# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
dt = keras.datasets.cifar100
(x_train,y_train),(x_test,y_test) = dt.load_data()
x_train,x_test = x_train/255.0,x_test/255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 13s 0us/step

# %%
import cv2

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[311])

# %%
model = keras.Sequential([
    layers.Flatten(input_shape = (32,32,3)),
    layers.Dense(256,activation = 'relu'),
    layers.Dense(128,activation = 'relu'),
    layers.Dense(64,activation = 'relu'),
    layers.Dense(100,activation = 'softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,validation_split=.1,epochs = 25)
# Out:
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1407/1407 [==============================] - 8s 4ms/step - loss: 4.2177 - accuracy: 0.0528 - val_loss: 4.0380 - val_accuracy: 0.0724
# Epoch 2/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.8235 - accuracy: 0.1131 - val_loss: 3.7955 - val_accuracy: 0.1160
# Epoch 3/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.6403 - accuracy: 0.1428 - val_loss: 3.6546 - val_accuracy: 0.1410
# Epoch 4/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.5379 - accuracy: 0.1592 - val_loss: 3.5788 - val_accuracy: 0.1566
# Epoch 5/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.4640 - accuracy: 0.1724 - val_loss: 3.5790 - val_accuracy: 0.1554
# Epoch 6/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.4039 - accuracy: 0.1834 - val_loss: 3.5049 - val_accuracy: 0.1598
# Epoch 7/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.3633 - accuracy: 0.1919 - val_loss: 3.4515 - val_accuracy: 0.1750
# Epoch 8/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.3247 - accuracy: 0.1976 - val_loss: 3.4495 - val_accuracy: 0.1836
# Epoch 9/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.2912 - accuracy: 0.2039 - val_loss: 3.4660 - val_accuracy: 0.1824
# Epoch 10/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.2637 - accuracy: 0.2088 - val_loss: 3.4451 - val_accuracy: 0.1856
# Epoch 11/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.2381 - accuracy: 0.2135 - val_loss: 3.4688 - val_accuracy: 0.1778
# Epoch 12/25
# 1407/1407 [==============================] - 6s 5ms/step - loss: 3.2156 - accuracy: 0.2163 - val_loss: 3.4727 - val_accuracy: 0.1798
# Epoch 13/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.1931 - accuracy: 0.2209 - val_loss: 3.4351 - val_accuracy: 0.1902
# Epoch 14/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.1703 - accuracy: 0.2258 - val_loss: 3.4091 - val_accuracy: 0.1994
# Epoch 15/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.1575 - accuracy: 0.2275 - val_loss: 3.4610 - val_accuracy: 0.1878
# Epoch 16/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.1361 - accuracy: 0.2308 - val_loss: 3.4252 - val_accuracy: 0.1936
# Epoch 17/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.1165 - accuracy: 0.2351 - val_loss: 3.4190 - val_accuracy: 0.1892
# Epoch 18/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.1003 - accuracy: 0.2392 - val_loss: 3.4554 - val_accuracy: 0.1964
# Epoch 19/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.0952 - accuracy: 0.2378 - val_loss: 3.3975 - val_accuracy: 0.2010
# Epoch 20/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.0831 - accuracy: 0.2390 - val_loss: 3.4558 - val_accuracy: 0.1988
# Epoch 21/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.0626 - accuracy: 0.2448 - val_loss: 3.4613 - val_accuracy: 0.1864
# Epoch 22/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.0501 - accuracy: 0.2488 - val_loss: 3.4069 - val_accuracy: 0.1974
# Epoch 23/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.0458 - accuracy: 0.2495 - val_loss: 3.4258 - val_accuracy: 0.1994
# Epoch 24/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.0348 - accuracy: 0.2503 - val_loss: 3.5018 - val_accuracy: 0.1846
# Epoch 25/25
# 1407/1407 [==============================] - 5s 4ms/step - loss: 3.0204 - accuracy: 0.2533 - val_loss: 3.4426 - val_accuracy: 0.1976

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train data','validation data'],loc = 'lower right')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train data','validation data'],loc = 'lower right')

# %%
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred,axis = 1)
y_pred
# Out:
# 313/313 [==============================] - 1s 2ms/step
# array([12, 31, 89, ..., 18, 42, 70])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.2056

# %%
img = x_test[560]
plt.imshow(img)
plt.xlabel(f"Y_pred{y_pred[560]} ,Y_test{y_test[560]}")
# Out:
# Text(0.5, 0, 'Y_pred91 ,Y_test[73]')
